# %% [markdown]
# <a href="https://colab.research.google.com/github/Kauaneeurich/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1**   🎼 ☎ 🚘

# %%
ano = "IV"
print(ano, "competição de programação da Start")
# Out:
# IV competição de programação da Start

# %% [markdown]
# #**Aula 2**   ⚡ ⛰ ⛈

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6

pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana =  2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# #**Aula 3**     ⏰ ⚾ ✅

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))

figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo

figurinhas_extras = int(input("Digite o número de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)

figurinhas_joao2 = figurinhas_extras * 2

print(f"João recebeu {figurinhas_joao} figurinhas")
print(f"João recebeu {figurinhas_joao2} figurinhas extras")

# %% [markdown]
# #**Aula 4**    👽 ✅ ⛔
#
#   ##Dia de prova

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")

# %% [markdown]
# #**Aula 5 - Cálculo de IMC**   ▶ 🚴 🥇

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))

imc = peso / (altura ** 2)

print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")

# %% [markdown]
# ##***Aula 6 Tabuada***  🏇 🐕 🐻

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")

numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# #**Aula 7 Idades** 🎱 💣 🔥

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima

resultado = calcula_idade_maior(68, 12, 30)
print(resultado)

# %% [markdown]
# #**Aula 8**     ✨  💙  🔐

# %%
print("sou seu assistente virtual \n")
nome = input("digite seu nome: ")

print(f"olá {nome}, em que posso ajudar?")
resposta = input("Qual assunto você deseja tratar? Matemática, Python ou Javascripit: \n").lower()

if resposta == "python":
  print("Ótimo, vamos falar sobre Python!")
print("")

elif resposta == "matemática":
  print("Perfeito, vamos resolver umas questões de matemática!")
elif resposta == "javascripit":
  print("Que legal, vamos conversar sobre javascript!")
else:
  print("Hum, não sei falar sobre esse assunto ")

# %% [markdown]
# #**Aula 9** Listas ⚓ ⭐ 💤

# %%
import random
dica = [
  "Acredite no seu potencial e voe alto. 🌌",
  "O sucesso é a soma de pequenos esforços. 🧩",
  "Hoje é o dia perfeito para começar. ☀️",
  "Nunca desista dos seus sonhos. 🦄",
  "Seja a mudança que você deseja ver no mundo. 🗺️",
  "A persistência realiza o impossível. 🧗",
  "Você é mais forte do que pensa. 💪",
  "Cada passo conta na sua jornada. 👣",
  "Mantenha o foco e siga em frente. 🎯",
  "A felicidade está nas coisas simples. 🎈",
]


while True:
  pedido = ("Digite 'dica' para receber uma dica ou 'sair' para encerrar").lower()

if pedido == "dica":
   dica = random.choice(dica) # escolhe uma dica aleatória
   print(f"dica: {dica}")
elif pedido == "sair":
   print("até mais")
   break
else:
   print("comando não reconhecido. Tente novamente.")
